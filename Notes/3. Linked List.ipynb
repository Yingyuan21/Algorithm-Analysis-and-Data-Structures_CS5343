# %% [markdown]
# # Single Linked List

# %% [markdown]
# 1. sum up all elements
# ```java
# int sum(Node tmp){
#     if tmp == null, return null;
#     else return tmp.val + sum(tmp.next);
# }
# ```

# %% [markdown]
# 2. print all element
# + Iteration
# ```java
# void trav(node tmp){
#     while(tmp!= null){
#         print tmp.val;
#         tmp = tmp.next;
#     }
# }
# ```
# + Recursion
# ```java
# void rtrav(node tmp){
#     if tmp == null, return;
#     print tmp.val;
#     retrun rtrav(tmp.next);
# }
# ```

# %% [markdown]
# 3. insert
# <br>5->7->9->1->3
# * insert after 9
# ```java
# insertA(ref, nd){
#     tmp = head;
#     while (tmp.val != ref){
#         tmp = tmp.next;
#     }
#     nd.next = tmp.next;
#     tmp.next = nd;
# }
# ```
# * insert before 9
# ```java
# insertB(ref, nd){
#     tmp = head;
#     if (tmp.val = ref){
#         nd.next = tmp;
#         head = nd;
#         return;
#     }
#     while (tmp.next.val != ref){
#         tmp = tmp.next;
#     }
#     nd.next = tmp.next;
#     tmp.next = nd;
# }
# ```

# %% [markdown]
# 4. delete
# ```java
# delete(nd){
#     tmp = head;
#     if (tmp.vall = nd){
#         head = tmp.next;
#         return;
#     }
#     while(tmp.next.val != nd){
#         tmp = tmp.next;
#     }
#     tmp.next = tmp.next.next;
# }
# ```

# %% [markdown]
# 5. Write a revursive algorithm to count # of node in the list, if empty return null
# ```java
# main( ){
#     n = count(head);
# }
# int count(node tmp){
#     if tmp == null, return null;
#     return 1 + count(tmp.next);
# }
# ```

# %% [markdown]
# 6. Write a recursive algorithm to find the largest value in the list. Assume at least one in the list.
# ```java
# main( ){
#     n = large(head);
# }
# int large (node tmp){
#     if (tmp.next == null) {return tmp.val;}
#     return max(tmp.val, large(tmp.next))
# }
# ```

# %% [markdown]
# 7. Given a single linked list, add all the values, return null if list is empty. use Recursive.
# ```java
# main( ){
#     s = sum(head);
# }
# int sum(node tmp){
#     if (tmp == null) return null;
#     return tmp.val + sum(tmp.next);
# }
# ```

# %% [markdown]
# 8. Write an Append() Algorithm that takes two single-linked lists, 'a' and 'b', appends 'b' onto the end of 'a'.
# ```java
# main(){
#     Append(heada, headb);
# }
# node Append(node tmp1, node tmp2){
#     if (tmp1 == null) return tmp2;
#     if (tmp2 == null) return tmp1;
#     node nd = tmp1;
#     while (nd.next != null){
#         nd = nd.next;
#     }
#     nd.next = tmp2;
#     return tmp1;
# }
# ```

# %% [markdown]
# 9. recursive algorithm single linked list. Assume # of nodes is odd. Find the middle.
# ```java
# main(){
#     n = mid(head, head.next);
# }
# node mid(tmp1, tmp2){
#     if (tmp2 == null) return tmp1;
#     return mid(tmp1.next, tmp2.next.next);
# }
# ```

# %% [markdown]
# 10. single linked list mess up: point to other position. recursive algorithm Single linked list. Find if list is messed up. Assume at least one node.
# ```java
# main(){
#     mess(head, head.next);
# }
# boolean mess(node tmp1, node tmp2){
#     if (tmp1 == tmp2) retrun true;
#     if (tmp2 == null) || (tmp2.next == null) return false;
#     return mess(tmp1.next, tmp2.next.next)
# }
# ```
# <br>e.g.
# //if messed up, there is a circle
# <br>7 -> 9 -> 3 <-> 2 6 4
# <br>mess(7,9). return(9,2), return(3, 2), return(2,2)

# %% [markdown]
# # Doubly Linked List

# %% [markdown]
# 1. recursive travers
# ```java
# rtrav(tmp){
#     if (tmp == null) return;
#     print tmp.val;
#     return rtrav(tmp.prev);
# }
# ```

# %% [markdown]
# 2. insert after the reference value
# * after the reference value
# ```java
# insertA(ref, nd){
#     if (tail.val == ref){
#         nd.next = null;
#         nd.prev = tail;
#         tail.next = nd;
#         tail = nd;
#         return;
#     }
#     tmp = head;
#     while(tmp.val != ref){
#         tmp = tmp.next;
#     }
#     nd.next = tmp.next;
#     nd.prev = tmp;
#     tmp.next.prev = nd;
#     tmp.next = nd;
# }
# ```
# * before the reference value
# ```java
# insertB(ref, nd){
#     if(head.val == ref){
#         nd.next = head;
#         nd.prev = null;
#         head.prev = nd;
#         head = nd;
#         return
#     }
#     tmp = head;
#     while(tmp.val!= ref){
#         tmp = tmp.next;
#     }
#     nd.next = tmp;
#     nd.prev = tmp.prev;
#     tmp.prev.next = nd;
#     tmp.prev = nd;
# }
# ```

# %% [markdown]
# 3. delete
# ```java
# delete(nd){
#     if (head.val == nd){
#         if(head == tail){
#             head == null;
#             tail == null;
#             return;
#         }
#         head = head.next;
#         head.prev = null;
#     }
#     if (tail.val == nd){
#         tail = tail.prev;
#         tail.next = null;
#     }
#     tmp = head;
#     while(tmp.val != nd){
#         tmp = tmp.next;
#     }
#     tmp.next.prev = tmp.prev;
#     tmp.prev.next = tmp.next;
# }
# ```

# %% [markdown]
# 4. recursive algorithm double linked list. Assume # of nodes is odd. Find the middle.
# ```java
# main(){
#     n = mid(head, tail)
# }
# mid(tmp1, tmp2){
#     if(tmp1 == tmp2) return tmp1;
#     return mid(tmp1.next, tmp2.prev);
# }
# ```
